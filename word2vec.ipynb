# %%
import numpy as np
import pandas as pd
from unidecode import unidecode
import nltk
import os
import re
from gensim.models import Word2Vec, KeyedVectors
from string import punctuation
#Pode ser alterado de acordo com a banda ou parcela do dataset escolhida. Existem musicas em diferentes linguas no dataset.
stopwords = nltk.corpus.stopwords.words('english')
#stopwords = nltk.corpus.stopwords.words('portuguese')
from nltk.stem import SnowballStemmer
import warnings
warnings.filterwarnings('ignore')

# %%
pontuacao = list(punctuation)
# Função pra remover pontuação, stopwords e numeros de textos, pois essas são informações irrelevantes 
pontuacao.append('...')
pontuacao.append('\"')
pontuacao.append('\'')
pontuacao.append('``')
pontuacao.append('`')
pontuacao.append('\n')
pontuacao.append('\t')
pontuacao.append('\’')

def processa(txt):
    for p in pontuacao:
        txt = str(txt).replace(p, ' ')
    return ' '.join([t for t in txt.lower().split() 
                     if (len(t)>2) 
                     if not re.search('^\d', t) 
                     and not re.search('.*\d$', t) 
                     and (t not in stopwords)])

# %%
# Lendo os datasets
df1 = pd.read_csv('./music/lyrics1.csv')
df2 = pd.read_csv('./music/lyrics2.csv')
df3 = pd.read_csv('./music/lyrics3.csv')
df4 = pd.read_csv('./music/lyrics4.csv')
df5 = pd.read_csv('./music/lyrics5.csv')
df6 = pd.read_csv('./music/lyrics6.csv')
df7 = pd.read_csv('./music/lyrics7.csv')
df8 = pd.read_csv('./music/lyrics8.csv')
df9 = pd.read_csv('./music/lyrics9.csv')


# Concatenando os 2 datasets
df =  pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9])
df.head()
# Out:
#    Unnamed: 0          Band  \
# 0           0  Elijah Blake
# 1           1  Elijah Blake
# 2           2  Elijah Blake
# 3           3  Elijah Blake
# 4           4  Elijah Blake
#
#                                               Lyrics                Song
# 0  No, no\r\nI ain't ever trapped out the bando\r...            Everyday
# 1  The drinks go down and smoke goes up, I feel m...    Live Till We Die
# 2  She don't live on planet Earth no more\r\nShe ...       The Otherside
# 3  Trippin' off that Grigio, mobbin', lights low\...               Pinot
# 4  I see a midnight panther, so gallant and so br...  Shadows & Diamonds

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head()
# Out:
#            Band                                             Lyrics  \
# 0  Elijah Blake  No, no\r\nI ain't ever trapped out the bando\r...
# 1  Elijah Blake  The drinks go down and smoke goes up, I feel m...
# 2  Elijah Blake  She don't live on planet Earth no more\r\nShe ...
# 3  Elijah Blake  Trippin' off that Grigio, mobbin', lights low\...
# 4  Elijah Blake  I see a midnight panther, so gallant and so br...
#
#                  Song
# 0            Everyday
# 1    Live Till We Die
# 2       The Otherside
# 3               Pinot
# 4  Shadows & Diamonds

# %%
df.shape
# Out:
# (516174, 3)

# %%
# Escolha uma ou mais bandas para treinar seu modelo
minhas_musicas = df[df['Band']=='Linkin Park']

# %%
minhas_musicas.head()
# Out:
#               Band                                             Lyrics  \
# 22562  Linkin Park  I break down, fear is sinking in\r\nThe cold c...
# 22563  Linkin Park  I remembered black skies / the lightning all a...
# 22564  Linkin Park  What do I do to ignore them behind me?\r\nDo I...
# 22565  Linkin Park  Crawling in my skin\r\nThese wounds, they will...
# 22566  Linkin Park  Folks, we have a very special guest for you to...
#
#                     Song
# 22562          Not Alone
# 22563  New Divide [Live]
# 22564          By Myself
# 22565           Crawling
# 22566  Cure for the Itch

# %%
minhas_musicas.shape
# Out:
# (137, 3)

# %%
minhas_musicas['musica_processada'] = minhas_musicas['Lyrics'].apply(lambda x: processa(x))

minhas_musicas.head()
# Out:
#               Band                                             Lyrics  \
# 22562  Linkin Park  I break down, fear is sinking in\r\nThe cold c...
# 22563  Linkin Park  I remembered black skies / the lightning all a...
# 22564  Linkin Park  What do I do to ignore them behind me?\r\nDo I...
# 22565  Linkin Park  Crawling in my skin\r\nThese wounds, they will...
# 22566  Linkin Park  Folks, we have a very special guest for you to...
#
#                     Song                                  musica_processada
# 22562          Not Alone  break fear sinking cold comes racing skin sear...
# 22563  New Divide [Live]  remembered black skies lightning around rememb...
# 22564          By Myself  ignore behind follow instincts blindly hide pr...
# 22565           Crawling  crawling skin wounds heal fear fall confusing ...
# 22566  Cure for the Itch  folks special guest tonight would like introdu...

# %%
# Criando o corpus. Vale ressaltar que o corpus é uma lista de listas.
corpus = []

# %%
# Percorre linha or linha do dataset
for i in minhas_musicas.iterrows():
    corpus.append(i[1]['musica_processada'].split())

# %%
corpus
# Out:
# [['break',
#   'fear',
#   'sinking',
#   'cold',
#   'comes',
#   'racing',
#   'skin',
#   'searching',
#   'way',
#   'get',
#   'storm',
#   'giving',
#   'home',
#   'leaving',
#   'known',
#   'alone',
#   'arms',
#   'stretched',
#   'sky',
#   'eyes',
#   'like',
#   'echoes',
#   'night',
#   'hiding',
#   'hell',
#   'silent',
#   'one',
#   'giving',
#   'home',
#   'leaving',
#   'known',
#   'giving',
#   'home',
#   'leaving',
#   'known',
#   'alone',
#   'giving',
#   'home',
#   'leaving',
#   'known',
#   'giving',
#   'home',
#   'alone',
#   'alone',
#   'alone'],
#  ['remembered',
#   'black',
#   'skies',
#   'lightning',
#   'around',
#   'remembered',
#   'flash',
#   'time',
#   'began',
#   'blur',
#   'like',
#   'startling',
#   'sign',
#   'fate',
#   'finally',
#   'found',
#   'voice',
#   'heard',
#   'get',
#   'deserve',
#   'give',
#   'reason',
#   'prove',
#   'wrong',
#   'wash',
#   'memory',
#   'clean',
#   'let',
#   'floods',
#   'cross',
#   'distance',
#   'eyes',
#   'give',
#   'reason',
#   'fill',
#   'hole',
#   'connect',
#   'space',
#   'let',
#   'enough',
#   'reach',
#   'truth',
#   'lies',
#   'across',
#   'new',
#   'divide',
#   'nothing',
#   'sight',
#   'memories',
#   'left',
#   'abandoned',
#   'nowhere',
#   'hide',
#   'ashes',
#   'fell',
#   'like',
#   'snow',
#   'ground',
#   'caved',
#   'standing',
#   'voice',
#   'heard',
#   'get',
#   'deserve',
#   'give',
#   'reason',
#   'prove',
#   'wrong',
#   'wash',
#   'memory',
#   'clean',
#   'let',
#   'floods',
#   'cross',
#   'distance',
#   'eyes',
#   'across',
#   'new',
#   'divide',
#   'every',
#   'loss',
#   'every',
#   'lie',
#   'every',
#   'truth',
#   'deny',
#   'regret',
#   'goodbye',
#   'mistake',
#   'great',
#   'hide',
#   'voice',
#   'heard',
#   'get',
#   'deserve',
#   'give',
#   'reason',
#   'prove',
#   'wrong',
#   'wash',
#   'memory',
#   'clean',
#   'let',
#   'floods',
#   'cross',
#   'distance',
#   'eyes',
#   'give',
#   'reason',
#   'fill',
#   'hole',
#   'connect',
#   'space',
#   'let',
#   'enough',
#   'reach',
#   'truth',
#   'lies',
#   'across',
#   'new',
#   'divide'],
#  ['ignore',
#   'behind',
#   'follow',
#   'instincts',
#   'blindly',
#   'hide',
#   'pride',
#   'bad',
#   'dreams',
#   'give',
#   'sad',
#   'thoughts',
#   'maddening',
#   'sit',
#   'try',
#   'stand',
#   'try',
#   'catch',
#   'red',
#   'handed',
#   'trust',
#   'get',
#   'fooled',
#   'phoniness',
#   'trust',
#   'nobody',
#   'live',
#   'loneliness',
#   'hold',
#   'stretched',
#   'thin',
#   'make',
#   'right',
#   'moves',
#   'lost',
#   'within',
#   'put',
#   'daily',
#   'facade',
#   'end',
#   'getting',
#   'hurt',
#   'ask',
#   'mind',
#   'find',
#   'rely',
#   'ask',
#   'mind',
#   'find',
#   'rely',
#   'hold',
#   'want',
#   'stretched',
#   'thin',
#   'much',
#   'take',
#   'hold',
#   'end',
#   'things',
#   'watching',
#   'everything',
#   'spin',
#   'thoughts',
#   'failure',
#   'sinking',
#   'turn',
#   'back',
#   'defenseless',
#   'blindly',
#   'seems',
#   'senseless',
#   'hide',
#   'pride',
#   'let',
#   'take',
#   'till',
#   'everything',
#   'gone',
#   'let',
#   'outdone',
#   'try',
#   'catch',
#   'outrun',
#   'killed',
#   'questions',
#   'like',
#   'cancer',
#   'buried',
#   'silence',
#   'answer',
#   'ask',
#   'mind',
#   'find',
#   'rely',
#   'ask',
#   'mind',
#   'find',
#   'rely',
#   'hold',
#   'want',
#   'stretched',
#   'thin',
#   'much',
#   'take',
#   'hold',
#   'end',
#   'things',
#   'watching',
#   'everything',
#   'spin',
#   'thoughts',
#   'failure',
#   'sinking',
#   'think',
#   'lost',
#   'much',
#   'afraid',
#   'touch',
#   'expect',
#   'know',
#   'know',
#   'tell',
#   'tell',
#   'make',
#   'matter',
#   'hard',
#   'seem',
#   'convince',
#   'stuck',
#   'outside',
#   'tell',
#   'make',
#   'matter',
#   'hard',
#   'seem',
#   'convince',
#   'stuck',
#   'outside',
#   'hold',
#   'want',
#   'stretched',
#   'thin',
#   'much',
#   'take',
#   'hold',
#   'anything',
#   'watching',
#   'everything',
#   'spin',
#   'without',
#   'failure',
#   'sinking',
#   'hold',
#   'want',
#   'stretched',
#   'thin',
#   'much',
#   'take',
#   'hold',
#   'anything',
#   'watching',
#   'everything',
#   'spin',
#   'without',
#   'failure',
#   'sinking'],
#  ['crawling',
#   'skin',
#   'wounds',
#   'heal',
#   'fear',
#   'fall',
#   'confusing',
#   'real',
#   'something',
#   'inside',
#   'pulls',
#   'beneath',
#   'surface',
#   'consuming',
#   'confusing',
#   'lack',
#   'self',
#   'control',
#   'fear',
#   'never',
#   'ending',
#   'controlling',
#   'seem',
#   'find',
#   'walls',
#   'closing',
#   'without',
#   'sense',
#   'confidence',
#   'convinced',
#   'much',
#   'pressure',
#   'take',
#   'felt',
#   'way',
#   'insecure',
#   'crawling',
#   'skin',
#   'wounds',
#   'heal',
#   'fear',
#   'fall',
#   'confusing',
#   'real',
#   'discomfort',
#   'endlessly',
#   'pulled',
#   'upon',
#   'distracting',
#   'reacting',
#   'stand',
#   'beside',
#   'reflection',
#   'haunting',
#   'seem',
#   'find',
#   'walls',
#   'closing',
#   'without',
#   'sense',
#   'confidence',
#   'convinced',
#   'much',
#   'pressure',
#   'take',
#   'felt',
#   'way',
#   'insecure',
#   'crawling',
#   'skin',
#   'wounds',
#   'heal',
#   'fear',
#   'fall',
#   'confusing',
#   'real',
#   'crawling',
#   'skin',
#   'wounds',
#   'heal',
#   'fear',
#   'fall',
#   'confusing',
#   'confusing',
#   'real',
#   'something',
#   'inside',
#   'pulls',
#   'beneath',
#   'surface',
#   'consuming',
#   'confusing',
#   'real',
#   'lack',
#   'self',
#   'control',
#   'fear',
#   'never',
#   'ending',
#   'controlling',
#   'confusing',
#   'real'],
#  ['folks',
#   'special',
#   'guest',
#   'tonight',
#   'would',
#   'like',
#   'introduce',
#   'hahn',
#   'let',
#   'hear',
#   'great',
#   'hahn',
#   'lesson',
#   'rhythm',
#   'management',
#   'let',
#   'begin',
#   'alright',
#   'fun',
#   'let',
#   'try',
#   'something',
#   'else'],
#  ['top',
#   'bottom',
#   'bottom',
#   'top',
#   'stop',
#   'core',
#   'forgotten',
#   'middle',
#   'thoughts',
#   'taken',
#   'far',
#   'safety',
#   'picture',
#   'memory',
#   'escape',
#   'care',
#   'top',
#   'bottom',
#   'bottom',
#   'top',
#   'stop',
#   'core',
#   'forgotten',
#   'middle',
#   'thoughts',
#   'taken',
#   'far',
#   'safety',
#   'picture',
#   'memory',
#   'escape',
#   'care',
#   'place',
#   'dark',
#   'see',
#   'end',
#   'skies',
#   'cock',
#   'back',
#   'shock',
#   'defend',
#   'rain',
#   'sends',
#   'dripping',
#   'acidic',
#   'questions',
#   'forcefully',
#   'power',
#   'suggestion',
#   'eyes',
#   'shut',
#   'looking',
#   'thought',
#   'rust',
#   'rotten',
#   'dust',
#   'spot',
#   'light',
#   'floods',
#   'floor',
#   'pours',
#   'rusted',
#   'world',
#   'pretend',
#   'eyes',
#   'ease',
#   'open',
#   'dark',
#   'top',
#   'bottom',
#   'bottom',
#   'top',
#   'stop',
#   'core',
#   'forgotten',
#   'middle',
#   'thoughts',
#   'taken',
#   'far',
#   'safety',
#   'picture',
#   'memory',
#   'escape',
#   'care',
#   'memory',
#   'find',
#   'eyes',
#   'burning',
#   'darkness',
#   'holding',
#   'tightly',
#   'sun',
#   'rises',
#   'moving',
#   'around',
#   'screaming',
#   'ups',
#   'downs',
#   'pollution',
#   'manifested',
#   'perpetual',
#   'sound',
#   'wheels',
#   'round',
#   'sunset',
#   'creeps',
#   'past',
#   'street',
#   'lamps',
#   'chain',
#   'link',
#   'concrete',
#   'little',
#   'piece',
#   'paper',
#   'picture',
#   'drawn',
#   'floats',
#   'street',
#   'til',
#   'wind',
#   'gone',
#   'memory',
#   'like',
#   'picture',
#   'paper',
#   'crumpled',
#   'perfect',
#   'top',
#   'bottom',
#   'bottom',
#   'top',
#   'stop',
#   'core',
#   'forgotten',
#   'middle',
#   'thoughts',
#   'taken',
#   'far',
#   'safety',
#   'picture',
#   'memory',
#   'escape',
#   'care',
#   'top',
#   'bottom',
#   'bottom',
#   'top',
#   'stop',
#   'core',
#   'forgotten',
#   'middle',
#   'thoughts',
#   'taken',
#   'far',
#   'safety',
#   'picture',
#   'memory',
#   'escape',
#   'care',
#   'memory',
#   'find',
#   'eyes',
#   'burning',
#   'darkness',
#   'holding',
#   'tightly',
#   'sun',
#   'rises',
#   'got',
#   'caught',
#   'act',
#   'bring',
#   'thought',
#   'back',
#   'telling',
#   'see',
#   'right',
#   'got',
#   'caught',
#   'act',
#   'bring',
#   'thought',
#   'back',
#   'telling',
#   'see',
#   'right',
#   'got',
#   'caught',
#   'act',
#   'bring',
#   'thought',
#   'back',
#   'telling',
#   'see',
#   'right',
#   'got',
#   'caught',
#   'act',
#   'bring',
#   'thought',
#   'back',
#   'telling',
#   'see',
#   'right',
#   'got',
#   'caught',
#   'act',
#   'bring',
#   'thought',
#   'back',
#   'telling',
#   'see',
#   'right',
#   'got',
#   'caught',
#   'act',
#   'bring',
#   'thought',
#   'back',
#   'telling',
#   'see',
#   'right',
#   'got',
#   'caught',
#   'act',
#   'bring',
#   'thought',
#   'back',
#   'telling',
#   'see',
#   'right',
#   'memory',
#   'find',
#   'eyes',
#   'burning',
#   'darkness',
#   'holding',
#   'tightly',
#   'sun',
#   'rises',
#   'memory',
#   'find',
#   'eyes',
#   'burning',
#   'darkness',
#   'holding',
#   'tightly',
#   'sun',
#   'rises'],
#  ['starts',
#   'one',
#   'thing',
#   'know',
#   'even',
#   'matter',
#   'hard',
#   'try',
#   'keep',
#   'mind',
#   'designed',
#   'rhyme',
#   'explain',
#   'due',
#   'time',
#   'know',
#   'time',
#   'valuable',
#   'thing',
#   'watch',
#   'fly',
#   'pendulum',
#   'swings',
#   'watch',
#   'count',
#   'end',
#   'day',
#   'clock',
#   'ticks',
#   'life',
#   'away',
#   'unreal',
#   'look',
#   'watch',
#   'time',
#   'right',
#   'window',
#   'trying',
#   'hold',
#   'even',
#   'know',
#   'wasted',
#   'watch',
#   'kept',
#   'everything',
#   'inside',
#   'even',
#   'though',
#   'tried',
#   'fell',
#   'apart',
#   'meant',
#   'eventually',
#   'memory',
#   'time',
#   'tried',
#   'hard',
#   'got',
#   'far',
#   'end',
#   'even',
#   'matter',
#   'fall',
#   'lose',
#   'end',
#   'even',
#   'matter',
#   'one',
#   'thing',
#   'know',
#   'even',
#   'matter',
#   'hard',
#   'try',
#   'keep',
#   'mind',
#   'designed',
#   'rhyme',
#   'remind',
#   'time',
#   'tried',
#   'hard',
#   'spite',
#   'way',
#   'mocking',
#   'acting',
#   'like',
#   'part',
#   'property',
#   'remembering',
#   'times',
#   'fought',
#   'surprised',
#   'got',
#   'things',
#   'way',
#   'even',
#   'recognize',
#   'anymore',
#   'knew',
#   'back',
#   'comes',
#   'back',
#   'end',
#   'kept',
#   'everything',
#   'inside',
#   'even',
#   'though',
#   'tried',
#   'fell',
#   'apart',
#   'meant',
#   'eventually',
#   'memory',
#   'time',
#   'tried',
#   'hard',
#   'got',
#   'far',
#   'end',
#   'even',
#   'matter',
#   'fall',
#   'lose',
#   'end',
#   'even',
#   'matter',
#   'put',
#   'trust',
#   'pushed',
#   'far',
#   'one',
#   'thing',
#   'know',
#   'put',
#   'trust',
#   'pushed',
#   'far',
#   'one',
#   'thing',
#   'know',
#   'tried',
#   'hard',
#   'got',
#   'far',
#   'end',
#   'even',
#   'matter',
#   'fall',
#   'lose',
#   'end',
#   'even',
#   'matter'],
#  ['cannot',
#   'take',
#   'anymore',
#   'saying',
#   'everything',
#   'said',
#   'words',
#   'make',
#   'sense',
#   'find',
#   'bliss',
#   'ignorance',
#   'less',
#   'hear',
#   'less',
#   'say',
#   'find',
#   'anyway',
#   'like',
#   'everything',
#   'say',
#   'takes',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'cause',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'find',
#   'answers',
#   'clear',
#   'wish',
#   'could',
#   'find',
#   'way',
#   'disappear',
#   'thoughts',
#   'make',
#   'sense',
#   'find',
#   'bliss',
#   'ignorance',
#   'nothing',
#   'seems',
#   'away',
#   'like',
#   'everything',
#   'say',
#   'takes',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'cause',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'everything',
#   'say',
#   'takes',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'cause',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'shut',
#   'talking',
#   'shut',
#   'shut',
#   'shut',
#   'shut',
#   'talking',
#   'shut',
#   'shut',
#   'shut',
#   'shut',
#   'break',
#   'everything',
#   'say',
#   'takes',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'cause',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'everything',
#   'say',
#   'takes',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'cause',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break'],
#  ['feel',
#   'like',
#   'night',
#   'today',
#   'something',
#   'air',
#   'right',
#   'today',
#   'uptight',
#   'today',
#   'paranoia',
#   'got',
#   'left',
#   'know',
#   'stressed',
#   'first',
#   'pressure',
#   'fed',
#   'know',
#   'feels',
#   'like',
#   'voice',
#   'back',
#   'head',
#   'like',
#   'face',
#   'hold',
#   'inside',
#   'face',
#   'awakes',
#   'close',
#   'eyes',
#   'face',
#   'watches',
#   'every',
#   'time',
#   'lie',
#   'face',
#   'laughs',
#   'every',
#   'time',
#   'fall',
#   'watches',
#   'everything',
#   'know',
#   'time',
#   'sink',
#   'swim',
#   'face',
#   'inside',
#   'hearing',
#   'right',
#   'beneath',
#   'skin',
#   'like',
#   'paranoid',
#   'lookin',
#   'back',
#   'like',
#   'whirlwind',
#   'inside',
#   'head',
#   'like',
#   'stop',
#   'hearing',
#   'within',
#   'like',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin',
#   'know',
#   'got',
#   'face',
#   'points',
#   'mistakes',
#   'got',
#   'face',
#   'inside',
#   'paranoia',
#   'probably',
#   'worse',
#   'know',
#   'set',
#   'first',
#   'know',
#   'stand',
#   'everybody',
#   'acts',
#   'like',
#   'fact',
#   'matter',
#   'add',
#   'everybody',
#   'face',
#   'hold',
#   'inside',
#   'face',
#   'awakes',
#   'close',
#   'eyes',
#   'face',
#   'watches',
#   'every',
#   'time',
#   'lie',
#   'face',
#   'laughs',
#   'every',
#   'time',
#   'fall',
#   'watches',
#   'everything',
#   'know',
#   'time',
#   'sink',
#   'swim',
#   'face',
#   'inside',
#   'watching',
#   'right',
#   'inside',
#   'skin',
#   'like',
#   'paranoid',
#   'lookin',
#   'back',
#   'like',
#   'whirlwind',
#   'inside',
#   'head',
#   'like',
#   'stop',
#   'hearing',
#   'within',
#   'like',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin',
#   'like',
#   'paranoid',
#   'lookin',
#   'back',
#   'like',
#   'whirlwind',
#   'inside',
#   'head',
#   'like',
#   'stop',
#   'hearing',
#   'within',
#   'like',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin',
#   'sun',
#   'goes',
#   'feel',
#   'light',
#   'betray',
#   'sun',
#   'goes',
#   'feel',
#   'light',
#   'betray',
#   'like',
#   'paranoid',
#   'lookin',
#   'back',
#   'like',
#   'whirlwind',
#   'inside',
#   'head',
#   'like',
#   'stop',
#   'hearing',
#   'within',
#   'like',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin',
#   'like',
#   'paranoid',
#   'lookin',
#   'back',
#   'like',
#   'whirlwind',
#   'inside',
#   'head',
#   'like',
#   'stop',
#   'hearing',
#   'within',
#   'like',
#   'stop',
#   'hearing',
#   'within',
#   'like',
#   'stop',
#   'hearing',
#   'within',
#   'like',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin'],
#  ['watch',
#   'moon',
#   'sits',
#   'sky',
#   'dark',
#   'night',
#   'shining',
#   'light',
#   'sun',
#   'sun',
#   'give',
#   'light',
#   'moon',
#   'assuming',
#   'moon',
#   'going',
#   'owe',
#   'one',
#   'makes',
#   'think',
#   'act',
#   'favors',
#   'rapidly',
#   'turn',
#   'around',
#   'start',
#   'asking',
#   'things',
#   'want',
#   'back',
#   'sick',
#   'tension',
#   'sick',
#   'hunger',
#   'sick',
#   'acting',
#   'like',
#   'owe',
#   'find',
#   'another',
#   'place',
#   'feed',
#   'greed',
#   'find',
#   'place',
#   'rest',
#   'want',
#   'another',
#   'place',
#   'hate',
#   'say',
#   'understand',
#   'see',
#   'meant',
#   'want',
#   'energy',
#   'enemy',
#   'place',
#   'head',
#   'maybe',
#   'someday',
#   'like',
#   'step',
#   'people',
#   'like',
#   'run',
#   'away',
#   'people',
#   'thought',
#   'knew',
#   'remember',
#   'back',
#   'used',
#   'calm',
#   'used',
#   'strong',
#   'used',
#   'generous',
#   'known',
#   'wear',
#   'welcome',
#   'see',
#   'quiet',
#   'alone',
#   'sick',
#   'tension',
#   'sick',
#   'hunger',
#   'sick',
#   'acting',
#   'like',
#   'owe',
#   'find',
#   'another',
#   'place',
#   'feed',
#   'greed',
#   'find',
#   'place',
#   'rest',
#   'sick',
#   'tension',
#   'sick',
#   'hunger',
#   'sick',
#   'acting',
#   'like',
#   'owe',
#   'find',
#   'another',
#   'place',
#   'feed',
#   'greed',
#   'find',
#   'place',
#   'rest',
#   'want',
#   'another',
#   'place',
#   'hate',
#   'say',
#   'understand',
#   'see',
#   'meant',
#   'want',
#   'energy',
#   'enemy',
#   'place',
#   'head',
#   'try',
#   'take',
#   'best',
#   'away',
#   'try',
#   'take',
#   'best',
#   'away',
#   'try',
#   'take',
#   'best',
#   'away',
#   'try',
#   'take',
#   'best',
#   'away',
#   'try',
#   'take',
#   'best',
#   'away',
#   'try',
#   'take',
#   'best',
#   'away',
#   'try',
#   'take',
#   'best',
#   'away',
#   'try',
#   'take',
#   'best',
#   'away',
#   'want',
#   'another',
#   'place',
#   'hate',
#   'say',
#   'understand',
#   'see',
#   'meant',
#   'want',
#   'energy',
#   'enemy',
#   'place',
#   'head',
#   'shut',
#   'sick',
#   'tension',
#   'sick',
#   'hunger',
#   'sick',
#   'acting',
#   'like',
#   'owe',
#   'find',
#   'another',
#   'place',
#   'feed',
#   'greed',
#   'find',
#   'place',
#   'rest',
#   'sick',
#   'tension',
#   'sick',
#   'hunger',
#   'sick',
#   'acting',
#   'like',
#   'owe',
#   'find',
#   'another',
#   'place',
#   'feed',
#   'greed',
#   'find',
#   'place',
#   'rest'],
#  ['lied',
#   'way',
#   'always',
#   'last',
#   'smile',
#   'fake',
#   'sake',
#   'everything',
#   'falls',
#   'apart',
#   'even',
#   'people',
#   'never',
#   'frown',
#   'eventually',
#   'break',
#   'sacrifice',
#   'hiding',
#   'lie',
#   'everything',
#   'end',
#   'soon',
#   'find',
#   'time',
#   'left',
#   'watch',
#   'unwind',
#   'sacrifice',
#   'never',
#   'knowing',
#   'never',
#   'walked',
#   'away',
#   'played',
#   'way',
#   'see',
#   'testing',
#   'pushes',
#   'away',
#   'never',
#   'walked',
#   'away',
#   'played',
#   'way',
#   'see',
#   'testing',
#   'pushes',
#   'away',
#   'tried',
#   'like',
#   'everything',
#   'wanted',
#   'last',
#   'time',
#   'take',
#   'blame',
#   'sake',
#   'everything',
#   'falls',
#   'apart',
#   'even',
#   'people',
#   'never',
#   'frown',
#   'eventually',
#   'break',
#   'sacrifice',
#   'hiding',
#   'lie',
#   'everything',
#   'end',
#   'soon',
#   'find',
#   'time',
#   'left',
#   'watch',
#   'unwind',
#   'sacrifice',
#   'never',
#   'knowing',
#   'never',
#   'walked',
#   'away',
#   'played',
#   'way',
#   'see',
#   'testing',
#   'pushes',
#   'away',
#   'never',
#   'walked',
#   'away',
#   'played',
#   'way',
#   'see',
#   'testing',
#   'pushes',
#   'away',
#   'time',
#   'find',
#   'unwinds',
#   'sacrifice',
#   'hiding',
#   'lie',
#   'time',
#   'find',
#   'unwinds',
#   'sacrifice',
#   'never',
#   'knowing',
#   'never',
#   'walked',
#   'away',
#   'played',
#   'way',
#   'see',
#   'testing',
#   'pushes',
#   'away',
#   'never',
#   'walked',
#   'away',
#   'played',
#   'way',
#   'see',
#   'testing',
#   'pushes',
#   'away',
#   'pushes',
#   'away'],
#  ['graffiti',
#   'decorations',
#   'sky',
#   'dust',
#   'constant',
#   'wave',
#   'tension',
#   'top',
#   'broken',
#   'trust',
#   'lessons',
#   'taught',
#   'learned',
#   'never',
#   'true',
#   'find',
#   'question',
#   'point',
#   'finger',
#   'guilty',
#   'association',
#   'point',
#   'finger',
#   'wanna',
#   'run',
#   'away',
#   'never',
#   'say',
#   'goodbye',
#   'wanna',
#   'know',
#   'truth',
#   'instead',
#   'wondering',
#   'wanna',
#   'know',
#   'answers',
#   'lies',
#   'wanna',
#   'shut',
#   'door',
#   'open',
#   'mind',
#   'paper',
#   'bags',
#   'angry',
#   'voices',
#   'sky',
#   'dust',
#   'another',
#   'wave',
#   'tension',
#   'filled',
#   'talk',
#   'taking',
#   'action',
#   'words',
#   'never',
#   'true',
#   'find',
#   'question',
#   'point',
#   'finger',
#   'guilty',
#   'association',
#   'point',
#   'finger',
#   'wanna',
#   'run',
#   'away',
#   'never',
#   'say',
#   'goodbye',
#   'wanna',
#   'know',
#   'truth',
#   'instead',
#   'wondering',
#   'wanna',
#   'know',
#   'answers',
#   'lies',
#   'wanna',
#   'shut',
#   'door',
#   'open',
#   'mind',
#   'gonna',
#   'run',
#   'away',
#   'never',
#   'say',
#   'goodbye',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'never',
#   'wonder',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'open',
#   'mind',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'wanna',
#   'run',
#   'away',
#   'never',
#   'say',
#   'goodbye',
#   'wanna',
#   'know',
#   'truth',
#   'instead',
#   'wondering',
#   'wanna',
#   'know',
#   'answers',
#   'lies',
#   'wanna',
#   'shut',
#   'door',
#   'open',
#   'mind',
#   'wanna',
#   'run',
#   'away',
#   'open',
#   'mind',
#   'wanna',
#   'run',
#   'away',
#   'open',
#   'mind',
#   'wanna',
#   'run',
#   'away',
#   'open',
#   'mind',
#   'wanna',
#   'run',
#   'away',
#   'open',
#   'mind'],
#  ['woke',
#   'dream',
#   'today',
#   'cold',
#   'static',
#   'put',
#   'cold',
#   'feet',
#   'floor',
#   'forgot',
#   'yesterday',
#   'remembering',
#   'pretending',
#   'anymore',
#   'little',
#   'taste',
#   'hypocrisy',
#   'left',
#   'wake',
#   'mistake',
#   'slow',
#   'react',
#   'even',
#   'though',
#   'close',
#   'still',
#   'distant',
#   'bring',
#   'back',
#   'true',
#   'way',
#   'feel',
#   'promised',
#   'face',
#   'sound',
#   'voice',
#   'painted',
#   'memories',
#   'even',
#   'see',
#   'keeping',
#   'everything',
#   'inside',
#   'see',
#   'even',
#   'close',
#   'eyes',
#   'hit',
#   'hit',
#   'back',
#   'fall',
#   'floor',
#   'rest',
#   'day',
#   'stands',
#   'still',
#   'fine',
#   'line',
#   'things',
#   'wrong',
#   'pretend',
#   'past',
#   'real',
#   'trapped',
#   'memory',
#   'left',
#   'wake',
#   'mistake',
#   'slow',
#   'react',
#   'even',
#   'though',
#   'close',
#   'still',
#   'distant',
#   'bring',
#   'back',
#   'true',
#   'way',
#   'feel',
#   'promised',
#   'face',
#   'sound',
#   'voice',
#   'painted',
#   'memories',
#   'even',
#   'see',
#   'keeping',
#   'everything',
#   'inside',
#   'see',
#   'even',
#   'close',
#   'eyes',
#   'see',
#   'keeping',
#   'everything',
#   'inside',
#   'see',
#   'even',
#   'close',
#   'eyes',
#   'matter',
#   'far',
#   'come',
#   'wait',
#   'see',
#   'tomorrow',
#   'matter',
#   'far',
#   'come',
#   'wait',
#   'see',
#   'tomorrow',
#   'see',
#   'keeping',
#   'everything',
#   'inside',
#   'see',
#   'even',
#   'close',
#   'eyes',
#   'see',
#   'keeping',
#   'everything',
#   'inside',
#   'see',
#   'even',
#   'close',
#   'eyes'],
#  ['crawling',
#   'skin',
#   'wounds',
#   'heal',
#   'fear',
#   'fall',
#   'confusing',
#   'real',
#   'something',
#   'inside',
#   'pulls',
#   'beneath',
#   'surface',
#   'consuming',
#   'confusing',
#   'lack',
#   'self',
#   'control',
#   'fear',
#   'never',
#   'ending',
#   'controlling',
#   'seem',
#   'find',
#   'walls',
#   'closing',
#   'without',
#   'sense',
#   'confidence',
#   'convinced',
#   'much',
#   'pressure',
#   'take',
#   'felt',
#   'way',
#   'insecure',
#   'crawling',
#   'skin',
#   'wounds',
#   'heal',
#   'fear',
#   'fall',
#   'confusing',
#   'real',
#   'discomfort',
#   'endlessly',
#   'pulled',
#   'upon',
#   'distracting',
#   'reacting',
#   'stand',
#   'beside',
#   'reflection',
#   'haunting',
#   'seem',
#   'find',
#   'walls',
#   'closing',
#   'without',
#   'sense',
#   'confidence',
#   'convinced',
#   'much',
#   'pressure',
#   'take',
#   'felt',
#   'way',
#   'insecure',
#   'crawling',
#   'skin',
#   'wounds',
#   'heal',
#   'fear',
#   'fall',
#   'confusing',
#   'real',
#   'crawling',
#   'skin',
#   'wounds',
#   'heal',
#   'fear',
#   'fall',
#   'confusing',
#   'confusing',
#   'real',
#   'something',
#   'inside',
#   'pulls',
#   'beneath',
#   'surface',
#   'consuming',
#   'confusing',
#   'real',
#   'lack',
#   'self',
#   'control',
#   'fear',
#   'never',
#   'ending',
#   'controlling',
#   'confusing',
#   'real'],
#  ['taking',
#   'crates',
#   'ever',
#   'since',
#   'living',
#   'space',
#   'rat',
#   'race',
#   'monkeys',
#   'human',
#   'traits',
#   'mastered',
#   'numerology',
#   'big',
#   'bang',
#   'theology',
#   'digging',
#   'crates',
#   'ever',
#   'since',
#   'living',
#   'space',
#   'rat',
#   'race',
#   'monkeys',
#   'human',
#   'traits',
#   'mastered',
#   'numerology',
#   'big',
#   'bang',
#   'theology',
#   'preformed',
#   'lobotomies',
#   'telekinetic',
#   'psychology',
#   'invented',
#   'mic',
#   'could',
#   'start',
#   'blessing',
#   'chin',
#   'checking',
#   'kids',
#   'make',
#   'point',
#   'like',
#   'impressionist',
#   'many',
#   'men',
#   'tried',
#   'shake',
#   'twist',
#   'cords',
#   'like',
#   'double',
#   'helix',
#   'show',
#   'made',
#   'buckle',
#   'knees',
#   'like',
#   'leg',
#   'braces',
#   'cast',
#   'spell',
#   'instrumentalist',
#   'hate',
#   'try',
#   'leave',
#   'shoulder',
#   'cry',
#   'infinity',
#   'let',
#   'icons',
#   'bygones',
#   'fire',
#   'bombs',
#   'ghostly',
#   'notes',
#   'haunt',
#   'tried',
#   'threats',
#   'moved',
#   'promise',
#   'stomp',
#   'shit',
#   'without',
#   'accomplice',
#   'run',
#   'gauntlet',
#   'whoever',
#   'high',
#   'voltage',
#   'unforgettable',
#   'sound',
#   'high',
#   'voltage',
#   'bringing',
#   'taking',
#   'high',
#   'voltage',
#   'coming',
#   'every',
#   'side',
#   'high',
#   'voltage',
#   'making',
#   'rhythm',
#   'rhyme',
#   'collide',
#   'put',
#   'kink',
#   'backbones',
#   'clones',
#   'microphones',
#   'never',
#   'satisfied',
#   'rhymes',
#   'jones',
#   'spraying',
#   'bright',
#   'day',
#   'mite',
#   'say',
#   'blood',
#   'type',
#   'krylon',
#   'technicolor',
#   'type',
#   'highways',
#   'ripe',
#   'road',
#   'rage',
#   'pages',
#   'wind',
#   'cages',
#   'tin',
#   'bounce',
#   'around',
#   'surround',
#   'sound',
#   'devouring',
#   'scenes',
#   'subliminal',
#   'gangrene',
#   'paintings',
#   'things',
#   'sings',
#   'songs',
#   'karaoke',
#   'copy',
#   'bullshit',
#   'break',
#   'bones',
#   'verbally',
#   'stick',
#   'stones',
#   'tactics',
#   'fourth',
#   'dimension',
#   'compact',
#   'convection',
#   'write',
#   'rhymes',
#   'ease',
#   'track',
#   'stands',
#   'attention',
#   'meant',
#   'put',
#   'away',
#   'pencil',
#   'pistol',
#   'official',
#   'sixteen',
#   'lines',
#   'rhymes',
#   'missile',
#   'risk',
#   'pick',
#   'flaws',
#   'high',
#   'voltage',
#   'unforgettable',
#   'sound',
#   'high',
#   'voltage',
#   'bringin',
#   'takin',
#   'high',
#   'voltage',
#   'coming',
#   'every',
#   'side',
#   'high',
#   'voltage',
#   'making',
#   'rhythm',
#   'rhyme',
#   'collide',
#   'high',
#   'voltage',
#   'unforgettable',
#   'sound',
#   'high',
#   'voltage',
#   'bringin',
#   'takin',
#   'high',
#   'voltage',
#   'coming',
#   'every',
#   'side',
#   'high',
#   'voltage',
#   'making',
#   'rhythm',
#   'rhyme',
#   'collide',
#   'sometimes',
#   'sometimes',
#   'sometimes',
#   'sometimes',
#   'sometimes',
#   'sometimes',
#   'sometimes',
#   'sometimes',
#   'sometimes',
#   'feel',
#   'like',
#   'crawling',
#   'misunderstood',
#   'gun',
#   'like',
#   'new',
#   'disease',
#   'disease',
#   'disease',
#   'sometimes',
#   'feel',
#   'like',
#   'crawling',
#   'misunderstood',
#   'gun',
#   'like',
#   'new',
#   'disease',
#   'disease',
#   'disease',
#   'high',
#   'voltage',
#   'unforgettable',
#   'sound',
#   'high',
#   'voltage',
#   'bringin',
#   'takin',
#   'high',
#   'voltage',
#   'coming',
#   'every',
#   'side',
#   'high',
#   'voltage',
#   'making',
#   'rhythm',
#   'rhyme',
#   'collide',
#   'high',
#   'voltage',
#   'unforgettable',
#   'sound',
#   'high',
#   'voltage',
#   'bringin',
#   'takin',
#   'high',
#   'voltage',
#   'coming',
#   'every',
#   'side',
#   'high',
#   'voltage',
#   'making',
#   'rhythm',
#   'rhyme',
#   'collide',
#   'high',
#   'voltage',
#   'unforgetable',
#   'sound',
#   'high',
#   'voltage',
#   'bringin',
#   'takin',
#   'high',
#   'voltage',
#   'coming',
#   'every',
#   'side',
#   'high',
#   'voltage',
#   'making',
#   'rhythm',
#   'rhyme',
#   'collide',
#   'high',
#   'voltage',
#   'unforgetable',
#   'sound',
#   'high',
#   'voltage',
#   'bringin',
#   'takin',
#   'high',
#   'voltage',
#   'coming',
#   'every',
#   'side',
#   'high',
#   'voltage',
#   'making',
#   'rythm',
#   'ryhme',
#   'collide'],
#  ['december',
#   'time',
#   'year',
#   'december',
#   'clear',
#   'december',
#   'snow',
#   'covered',
#   'home',
#   'december',
#   'alone',
#   'wish',
#   'feel',
#   'like',
#   'something',
#   'missed',
#   'take',
#   'back',
#   'things',
#   'said',
#   'make',
#   'feel',
#   'like',
#   'wish',
#   'feel',
#   'like',
#   'something',
#   'missed',
#   'take',
#   'back',
#   'things',
#   'said',
#   'give',
#   'away',
#   'somewhere',
#   'give',
#   'away',
#   'someone',
#   'come',
#   'home',
#   'december',
#   'snow',
#   'covered',
#   'dreams',
#   'pretending',
#   'need',
#   'wish',
#   'feel',
#   'like',
#   'something',
#   'missed',
#   'take',
#   'back',
#   'things',
#   'said',
#   'make',
#   'feel',
#   'like',
#   'wish',
#   'feel',
#   'like',
#   'something',
#   'missed',
#   'take',
#   'back',
#   'things',
#   'said',
#   'give',
#   'away',
#   'somewhere',
#   'give',
#   'away',
#   'someone',
#   'come',
#   'home',
#   'december',
#   'time',
#   'year',
#   'december',
#   'clear',
#   'give',
#   'away',
#   'somewhere',
#   'give',
#   'away',
#   'someone',
#   'come',
#   'home'],
#  ['feel',
#   'like',
#   'night',
#   'today',
#   'something',
#   'right',
#   'today',
#   'uptight',
#   'today',
#   'paranoia',
#   'got',
#   'left',
#   'know',
#   'stressed',
#   'first',
#   'pressure',
#   'fed',
#   'know',
#   'feels',
#   'like',
#   'voice',
#   'back',
#   'head',
#   'like',
#   'face',
#   'hold',
#   'inside',
#   'like',
#   'face',
#   'awakes',
#   'close',
#   'eyes',
#   'face',
#   'watches',
#   'every',
#   'time',
#   'lie',
#   'face',
#   'laughs',
#   'every',
#   'time',
#   'fall',
#   'watches',
#   'everything',
#   'know',
#   'time',
#   'sink',
#   'swim',
#   'face',
#   'inside',
#   'hearing',
#   'right',
#   'underneath',
#   'skin',
#   'chorus',
#   'like',
#   'paranoid',
#   'lookin',
#   'back',
#   'like',
#   'whirlwind',
#   'inside',
#   'head',
#   'like',
#   'stop',
#   'hearing',
#   'within',
#   'like',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin',
#   'know',
#   'got',
#   'face',
#   'points',
#   'mistakes',
#   'got',
#   'face',
#   'inside',
#   'paranoia',
#   'probably',
#   'worse',
#   'know',
#   'set',
#   'first',
#   'know',
#   'stand',
#   'everybody',
#   'acts',
#   'like',
#   'fact',
#   'matter',
#   'add',
#   'everybody',
#   'face',
#   'hold',
#   'inside',
#   'face',
#   'awakes',
#   'close',
#   'eyes',
#   'face',
#   'watches',
#   'every',
#   'time',
#   'lie',
#   'face',
#   'laughs',
#   'every',
#   'time',
#   'fall',
#   'watches',
#   'everything',
#   'know',
#   'time',
#   'sink',
#   'swim',
#   'face',
#   'inside',
#   'watching',
#   'right',
#   'inside',
#   'skin',
#   'chorus',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin',
#   'sun',
#   'goes',
#   'feel',
#   'light',
#   'betray',
#   'chorus',
#   'like',
#   'paranoid',
#   'lookin',
#   'back',
#   'like',
#   'whirlwind',
#   'inside',
#   'head',
#   'like',
#   'stop',
#   'hearing',
#   'within',
#   'like',
#   'stop',
#   'hearing',
#   'within',
#   'like',
#   'stop',
#   'hearing',
#   'within',
#   'like',
#   'face',
#   'inside',
#   'right',
#   'beneath',
#   'skin'],
#  ['watch',
#   'room',
#   'rocks',
#   'men',
#   'moon',
#   'walk',
#   'mixed',
#   'media',
#   'slang',
#   'banging',
#   'boom',
#   'box',
#   'verbal',
#   'violence',
#   'lyrical',
#   'stylist',
#   'time',
#   'rock',
#   'hip',
#   'hop',
#   'rhymes',
#   'childish',
#   'tempt',
#   'rhymes',
#   'empty',
#   'rapping',
#   'beat',
#   'make',
#   'emcee',
#   'lack',
#   'skill',
#   'facility',
#   'killing',
#   'group',
#   'credibility',
#   'heard',
#   'getting',
#   'help',
#   'rhymes',
#   'emcee',
#   'someone',
#   'else',
#   'writes',
#   'lines',
#   'rapping',
#   'rock',
#   'make',
#   'pioneer',
#   'cause',
#   'rock',
#   'hip',
#   'hop',
#   'collaborated',
#   'years',
#   'getting',
#   'randomly',
#   'mixed',
#   'matched',
#   'fast',
#   'buck',
#   'tracks',
#   'suck',
#   'stack',
#   'none',
#   'real',
#   'want',
#   'emcee',
#   'got',
#   'study',
#   'skill',
#   'rock',
#   'rhyme',
#   'like',
#   'bring',
#   'every',
#   'time',
#   'like',
#   'rock',
#   'rhyme',
#   'like',
#   'step',
#   'step',
#   'step',
#   'step',
#   'pick',
#   'pen',
#   'write',
#   'new',
#   'identity',
#   'mentally',
#   'hip',
#   'hop',
#   'energy',
#   'tendency',
#   'make',
#   'stories',
#   'sounding',
#   'like',
#   'hip',
#   'hop',
#   'heard',
#   'top',
#   'record',
#   'company',
#   'completely',
#   'missing',
#   'kids',
#   'dissing',
#   'legitimate',
#   'battle',
#   'hack',
#   'react',
#   'whack',
#   'shit',
#   'get',
#   'smacked',
#   'verbal',
#   'back',
#   'flips',
#   'get',
#   'ass',
#   'kicked',
#   'fabulous',
#   'battle',
#   'catalysts',
#   'taken',
#   'decades',
#   'emcees',
#   'establish',
#   'new',
#   'hip',
#   'hop',
#   'welcome',
#   'serious',
#   'mic',
#   'leave',
#   'experienced',
#   'using',
#   'waves',
#   'sound',
#   'true',
#   'master',
#   'paralyzes',
#   'opponents',
#   'leaving',
#   'vulnerable',
#   'attack',
#   'rock',
#   'rhyme',
#   'like',
#   'bring',
#   'every',
#   'time',
#   'like',
#   'rock',
#   'rhyme',
#   'like',
#   'step',
#   'step',
#   'step',
#   'step',
#   'rock',
#   'rhyme',
#   'like',
#   'bring',
#   'every',
#   'time',
#   'like',
#   'rock',
#   'rhyme',
#   'like',
#   'step',
#   'step',
#   'step',
#   'step',
#   'step',
#   'years',
#   'pain',
#   'staking',
#   'research',
#   'world',
#   'leading',
#   'sound',
#   'scientists',
#   'sound',
#   'institute',
#   'invented',
#   'reliable',
#   'audio',
#   'weapons',
#   'system',
#   'actual',
#   'movement',
#   'musical',
#   'sound',
#   'space',
#   'used',
#   'carefully',
#   'attack',
#   'neutralize',
#   'cellular',
#   'structure',
#   'human',
#   'body',
#   'question',
#   'must',
#   'asked',
#   'rock',
#   'rhyme',
#   'like',
#   'bring',
#   'every',
#   'time',
#   'like',
#   'rock',
#   'rhyme',
#   'like',
#   'step',
#   'step',
#   'step',
#   'step',
#   'rock',
#   'rhyme',
#   'like',
#   'bring',
#   'every',
#   'time',
#   'like',
#   'rock',
#   'rhyme',
#   'like',
#   'step',
#   'step',
#   'step',
#   'step',
#   'step',
#   'mixed',
#   'media',
#   'step',
#   'microphone',
#   'like'],
#  ['forfeit',
#   'game',
#   'somebody',
#   'takes',
#   'frame',
#   'put',
#   'name',
#   'shame',
#   'cover',
#   'face',
#   'run',
#   'race',
#   'pace',
#   'fast',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'love',
#   'way',
#   'look',
#   'taking',
#   'pleasure',
#   'awful',
#   'things',
#   'put',
#   'take',
#   'away',
#   'give',
#   'life',
#   'pride',
#   'broken',
#   'like',
#   'think',
#   'never',
#   'wrong',
#   'like',
#   'think',
#   'never',
#   'wrong',
#   'act',
#   'like',
#   'someone',
#   'act',
#   'like',
#   'someone',
#   'want',
#   'someone',
#   'hurt',
#   'like',
#   'want',
#   'someone',
#   'hurt',
#   'like',
#   'want',
#   'share',
#   'live',
#   'learned',
#   'learned',
#   'learned',
#   'learned',
#   'learned',
#   'learned',
#   'love',
#   'things',
#   'say',
#   'way',
#   'hurt',
#   'get',
#   'back',
#   'take',
#   'away',
#   'give',
#   'life',
#   'pride',
#   'broken',
#   'like',
#   'think',
#   'never',
#   'wrong',
#   'like',
#   'think',
#   'never',
#   'wrong',
#   'act',
#   'like',
#   'someone',
#   'act',
#   'like',
#   'someone',
#   'want',
#   'someone',
#   'hurt',
#   'like',
#   'want',
#   'someone',
#   'hurt',
#   'like',
#   'wanna',
#   'share',
#   'live',
#   'learned',
#   'forfeit',
#   'game',
#   'somebody',
#   'takes',
#   'frame',
#   'put',
#   'name',
#   'shame',
#   'cover',
#   'face',
#   'run',
#   'race',
#   'pace',
#   'fast',
#   'last',
#   'forfeit',
#   'game',
#   'somebody',
#   'takes',
#   'frame',
#   'put',
#   'name',
#   'shame',
#   'cover',
#   'face',
#   'run',
#   'race',
#   'pace',
#   'fast',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'last',
#   'like',
#   'think',
#   'never',
#   'wrong',
#   'like',
#   'think',
#   'never',
#   'wrong',
#   'act',
#   'like',
#   'someone',
#   'act',
#   'like',
#   'someone',
#   'want',
#   'someone',
#   'hurt',
#   'like',
#   'want',
#   'someone',
#   'hurt',
#   'like',
#   'want',
#   'share',
#   'like',
#   'think',
#   'never',
#   'wrong',
#   'like',
#   'think',
#   'never',
#   'wrong',
#   'act',
#   'like',
#   'someone',
#   'act',
#   'like',
#   'someone',
#   'want',
#   'someone',
#   'hurt',
#   'like',
#   'want',
#   'someone',
#   'hurt',
#   'like',
#   'want',
#   'share',
#   'live',
#   'learned'],
#  ['ignore',
#   'behind',
#   'follow',
#   'instincts',
#   'blindly',
#   'hide',
#   'pride',
#   'bad',
#   'dreams',
#   'give',
#   'sad',
#   'thoughts',
#   'maddening',
#   'sit',
#   'try',
#   'stand',
#   'try',
#   'catch',
#   'red',
#   'handed',
#   'trust',
#   'get',
#   'fooled',
#   'phoniness',
#   'trust',
#   'nobody',
#   'live',
#   'loneliness',
#   'hold',
#   'stretched',
#   'thin',
#   'make',
#   'right',
#   'moves',
#   'lost',
#   'within',
#   'put',
#   'daily',
#   'facade',
#   'end',
#   'getting',
#   'hurt',
#   'ask',
#   'mind',
#   'find',
#   'rely',
#   'ask',
#   'mind',
#   'find',
#   'cant',
#   'rely',
#   'cant',
#   'look',
#   'around',
#   'much',
#   'take',
#   'cant',
#   'hold',
#   'stretched',
#   'thin',
#   'slow',
#   'watching',
#   'everything',
#   'spin',
#   'look',
#   'past',
#   'starting',
#   'turn',
#   'back',
#   'defenseless',
#   'blindly',
#   'seems',
#   'senseless',
#   'hide',
#   'pride',
#   'let',
#   'take',
#   'till',
#   'everything',
#   'gone',
#   'let',
#   'outdone',
#   'try',
#   'catch',
#   'outrun',
#   'killed',
#   'questions',
#   'like',
#   'cancer',
#   'buried',
#   'silence',
#   'answer',
#   'ask',
#   'mind',
#   'find',
#   'rely',
#   'ask',
#   'mind',
#   'find',
#   'rely',
#   'look',
#   'around',
#   'much',
#   'take',
#   'hold',
#   'stretched',
#   'thin',
#   'slow',
#   'watching',
#   'everything',
#   'spin',
#   'look',
#   'past',
#   'starting',
#   'said',
#   'repeatedly',
#   'background',
#   'know',
#   'tell',
#   'make',
#   'mater',
#   'hard',
#   'try',
#   'seem',
#   'convince',
#   'stuck',
#   'outside',
#   'know',
#   'tell',
#   'make',
#   'matter',
#   'hard',
#   'try',
#   'seem',
#   'convince',
#   'stuck',
#   'outside',
#   'know',
#   'tell',
#   'make',
#   'matter',
#   'hard',
#   'try',
#   'seem',
#   'convince',
#   'stuck',
#   'outside',
#   'know',
#   'cant',
#   'tell',
#   'make',
#   'matter',
#   'hard',
#   'try',
#   'seem',
#   'convince',
#   'stuck',
#   'outside',
#   'know',
#   'tell',
#   'make',
#   'matter',
#   'hard',
#   'try',
#   'seem',
#   'convince',
#   'stuck',
#   'outside',
#   'know',
#   'tell',
#   'make',
#   'matter',
#   'hard',
#   'try',
#   'seem',
#   'convince',
#   'stuck',
#   'outside'],
#  ['come',
#   'woke',
#   'dream',
#   'today',
#   'cold',
#   'static',
#   'put',
#   'cold',
#   'feet',
#   'floor',
#   'forgot',
#   'yesterday',
#   'remembering',
#   'pretending',
#   'anymore',
#   'little',
#   'taste',
#   'hypocrisy',
#   'left',
#   'wake',
#   'mistake',
#   'slow',
#   'react',
#   'even',
#   'though',
#   'close',
#   'still',
#   'distant',
#   'bring',
#   'back',
#   'true',
#   'way',
#   'feel',
#   'promised',
#   'face',
#   'sound',
#   'voice',
#   'painted',
#   'memories',
#   'even',
#   'see',
#   'keeping',
#   'everything',
#   'inside',
#   'see',
#   'even',
#   'close',
#   'eyes',
#   'see',
#   'keeping',
#   'everything',
#   'inside',
#   'see',
#   'even',
#   'close',
#   'eyes',
#   'ugh',
#   'hit',
#   'hit',
#   'back',
#   'fall',
#   'floor',
#   'rest',
#   'day',
#   'stands',
#   'still',
#   'fine',
#   'line',
#   'things',
#   'wrong',
#   'pretend',
#   'past',
#   'real',
#   'trapped',
#   'memory',
#   'left',
#   'wake',
#   'mistake',
#   'slow',
#   'react',
#   'even',
#   'though',
#   'close',
#   'still',
#   'distant',
#   'bring',
#   'back',
#   'true',
#   'way',
#   'feel',
#   'promised',
#   'face',
#   'sound',
#   'voice',
#   'painted',
#   'memories',
#   'even',
#   'see',
#   'keeping',
#   'everything',
#   'inside',
#   'see',
#   'even',
#   'close',
#   'eyes',
#   'see',
#   'keeping',
#   'everything',
#   'inside',
#   'see',
#   'even',
#   'close',
#   'eyes',
#   'ugh',
#   'let',
#   'control',
#   'fate',
#   'holding',
#   'weight',
#   'world',
#   'conscience',
#   'sit',
#   'wait',
#   'weighin',
#   'options',
#   'makin',
#   'fool',
#   'dare',
#   'try',
#   'say',
#   'care',
#   'solemnly',
#   'swear',
#   'follow',
#   'like',
#   'beg',
#   'knees',
#   'please',
#   'baby',
#   'please',
#   'doin',
#   'things',
#   'upset',
#   'angry',
#   'know',
#   'love',
#   'love',
#   'love',
#   'sometimes',
#   'pay',
#   'never',
#   'without',
#   'always',
#   'never',
#   'forget',
#   'keeping',
#   'let',
#   'take',
#   'end',
#   'row',
#   'keep',
#   'burning',
#   'torching',
#   'soul',
#   'puppet',
#   'let',
#   'matter',
#   'far',
#   'come',
#   'wait',
#   'see',
#   'tomorrow',
#   'matter',
#   'far',
#   'come',
#   'wait',
#   'see',
#   'tomorrow',
#   'see',
#   'keeping',
#   'everything',
#   'inside',
#   'see',
#   'even',
#   'close',
#   'eyes',
#   'see',
#   'keeping',
#   'everything',
#   'inside',
#   'see',
#   'even',
#   'close',
#   'eyes',
#   'ugh'],
#  ['reached',
#   'mike',
#   'give',
#   'detailed',
#   'please',
#   'enter',
#   'pass',
#   'first',
#   'message',
#   'mike',
#   'chali',
#   'wsup',
#   'man',
#   'trying',
#   'catch',
#   'man',
#   'ahead',
#   'get',
#   'song',
#   'roll',
#   'pot',
#   'haha',
#   'call',
#   'back',
#   'peace'],
#  ['next',
#   'message',
#   'hey',
#   'mike',
#   'roc',
#   'asking',
#   'happening',
#   'touching',
#   'base',
#   'seeing',
#   'easter',
#   'went',
#   'seeing',
#   'going',
#   'see',
#   'joe',
#   'sometime',
#   'soon',
#   'got',
#   'keyboard',
#   'trying',
#   'get',
#   'back',
#   'trying',
#   'call',
#   'returning',
#   'messages',
#   'seeing',
#   'best',
#   'angle',
#   'know',
#   'get',
#   'back',
#   'heyy',
#   'dude',
#   'good',
#   'idea',
#   'get',
#   'message',
#   'around',
#   'like'],
#  ['next',
#   'message',
#   'stef',
#   'call',
#   'going',
#   'town',
#   'week',
#   'want',
#   'get',
#   'track',
#   'taken',
#   'care',
#   'let',
#   'know',
#   'call',
#   'cell',
#   'right',
#   'late'],
#  ['break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'cause',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'break',
#   'room',
#   'breathe',
#   'room',
#   'breathe',
#   'room',
#   'breathe',
#   'cannot',
#   'take',
#   'anymore',
#   'saying',
#   'everything',
#   'said',
#   'words',
#   'make',
#   'sense',
#   'found',
#   'bliss',
#   'ignorance',
#   'less',
#   'hear',
#   'less',
#   'say',
#   'find',
#   'anyway',
#   'find',
#   'answers',
#   'clear',
#   'wish',
#   'could',
#   'find',
#   'way',
#   'disappear',
#   'thoughts',
#   'make',
#   'sense',
#   'found',
#   'bliss',
#   'ignorance',
#   'nothing',
#   'seems',
#   'away',
#   'like',
#   'everything',
#   'say',
#   'break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'break',
#   'everything',
#   'say',
#   'break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'break',
#   'places',
#   'feel',
#   'torn',
#   'body',
#   'flesh',
#   'peels',
#   'ride',
#   'cut',
#   'upwhat',
#   'like',
#   'break',
#   'waiting',
#   'alone',
#   'cannot',
#   'resist',
#   'feeling',
#   'hate',
#   'never',
#   'missed',
#   'please',
#   'someone',
#   'give',
#   'reason',
#   'rip',
#   'face',
#   'blood',
#   'pouring',
#   'pouring',
#   'pouring',
#   'pouring',
#   'pouring',
#   'pouring',
#   'pouring',
#   'pouring',
#   'pouring',
#   'pouring',
#   'shut',
#   'talking',
#   'shut',
#   'blood',
#   'pouring',
#   'shut',
#   'blood',
#   'pouring',
#   'shut',
#   'blood',
#   'pouring',
#   'shut',
#   'talking',
#   'shut',
#   'blood',
#   'pouring',
#   'shut',
#   'blood',
#   'pouring',
#   'shut',
#   'blood',
#   'pouring',
#   'shut',
#   'break',
#   'everything',
#   'say',
#   'break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'break',
#   'everything',
#   'say',
#   'break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'everything',
#   'say',
#   'takes',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'cause',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'everything',
#   'say',
#   'takes',
#   'one',
#   'step',
#   'closer',
#   'edge',
#   'break',
#   'need',
#   'little',
#   'room',
#   'breathe',
#   'cause',
#   'one',
#   'step',
#   'closer',
#   'edge'],
#  ['hey',
#   'first',
#   'started',
#   'linkin',
#   'park',
#   'middle',
#   'came',
#   'motion',
#   'man',
#   'end',
#   'kutmasta',
#   'kut',
#   'wit',
#   'remix',
#   'one',
#   'thing',
#   'know',
#   'even',
#   'matter',
#   'hard',
#   'try',
#   'keep',
#   'mind',
#   'designed',
#   'rhyme',
#   'obsessed',
#   'time',
#   'know',
#   'time',
#   'slipping',
#   'way',
#   'watched',
#   'count',
#   'till',
#   'end',
#   'day',
#   'watched',
#   'watch',
#   'words',
#   'say',
#   'echo',
#   'clock',
#   'rhythm',
#   'veins',
#   'know',
#   'look',
#   'watched',
#   'time',
#   'right',
#   'window',
#   'trying',
#   'grab',
#   'hold',
#   'trying',
#   'watch',
#   'wasted',
#   'hands',
#   'clock',
#   'end',
#   'matter',
#   'pretend',
#   'journey',
#   'important',
#   'end',
#   'start',
#   'meant',
#   'eventually',
#   'memory',
#   'time',
#   'tried',
#   'hard',
#   'tried',
#   'hard',
#   'got',
#   'far',
#   'end',
#   'even',
#   'matter',
#   'fall',
#   'lose',
#   'end',
#   'even',
#   'matter',
#   'one',
#   'thing',
#   'one',
#   'thing',
#   'know',
#   'even',
#   'matter',
#   'hard',
#   'try',
#   'keep',
#   'mind',
#   'designed',
#   'rhyme',
#   'explain',
#   'due',
#   'time',
#   'know',
#   'time',
#   'socialize',
#   'like',
#   'host',
#   'party',
#   'shake',
#   'made',
#   'eye',
#   'contact',
#   'party',
#   'control',
#   'showing',
#   'northeast',
#   'southwest',
#   'coast',
#   'stand',
#   'window',
#   'opportunity',
#   'mingle',
#   'tried',
#   'show',
#   'could',
#   'sense',
#   'middle',
#   'disorder',
#   'brought',
#   'back',
#   'thing',
#   'like',
#   'imaginary',
#   'man',
#   'dreams',
#   'well',
#   'would',
#   'always',
#   'seem',
#   'make',
#   'worth',
#   'pig',
#   'skin',
#   'never',
#   'nerved',
#   'felt',
#   'lever',
#   'never',
#   'pleather',
#   'real',
#   'bringing',
#   'pleasure',
#   'means',
#   'means',
#   'leaving',
#   'teens',
#   'holler',
#   'teen',
#   'magazines',
#   'tried',
#   'hard',
#   'tried',
#   'hard',
#   'got',
#   'far',
#   'end',
#   'even',
#   'matter',
#   'fall',
#   'lose',
#   'end',
#   'even',
#   'matter',
#   'linkin',
#   'park',
#   'remix',
#   'motion',
#   'man',
#   'linkin',
#   'park',
#   'end',
#   'kutmasta',
#   'kutmasta',
#   'kut',
#   'kutmasta',
#   'kurt',
#   'linkin',
#   'park',
#   'remix',
#   'motion',
#   'man',
#   'linkin',
#   'park',
#   'end',
#   'kutmasta',
#   'kurt',
#   'one',
#   'thing',
#   'know',
#   'even',
#   'matter',
#   'look',
#   'designed',
#   'rhyme',
#   'scared',
#   'scared',
#   'fall',
#   'even',
#   'tried',
#   'crawl',
#   'forced',
#   'run',
#   'mocking',
#   'stopping',
#   'back',
#   'stabbing',
#   'constantly',
#   'remembering',
#   'times',
#   'fought',
#   'watch',
#   'clock',
#   'chop',
#   'full',
#   'hypocrisy',
#   'mouth',
#   'wishes',
#   'could',
#   'inhale',
#   'every',
#   'single',
#   'little',
#   'thing',
#   'said',
#   'make',
#   'expel',
#   'every',
#   'single',
#   'word',
#   'sputter',
#   'get',
#   'piece',
#   'really',
#   'matter',
#   'start',
#   'end',
#   'matter',
#   'pretend',
#   'journey',
#   'important',
#   'end',
#   'start',
#   'meant',
#   'eventually',
#   'memory',
#   'time',
#   'tried',
#   'hard',
#   'tried',
#   'hard',
#   'got',
#   'far',
#   'end',
#   'even',
#   'matter',
#   'fall',
#   'lose',
#   'end',
#   'even',
#   'matter',
#   'end'],
#  ['traveler',
#   'repaid',
#   'debt',
#   'searching',
#   'trail',
#   'follow',
#   'take',
#   'back',
#   'night',
#   'met',
#   'tell',
#   'hell',
#   'supposed',
#   'tell',
#   'ride',
#   'along',
#   'none',
#   'take',
#   'back',
#   'night',
#   'met',
#   'know',
#   'supposed',
#   'haunted',
#   'ghost',
#   'take',
#   'back',
#   'night',
#   'met',
#   'night',
#   'full',
#   'terrors',
#   'eyes',
#   'filled',
#   'tears',
#   'touched',
#   'yet',
#   'take',
#   'back',
#   'night',
#   'met',
#   'none',
#   'take',
#   'back',
#   'night',
#   'met',
#   'know',
#   'supposed',
#   'haunted',
#   'ghost',
#   'take',
#   'back',
#   'night',
#   'met'],
#  ['sometimes',
#   'sometimes',
#   'sometimes',
#   'sometimes',
#   'hybrid',
#   'diggin',
#   'crates',
#   'ever',
#   'since',
#   'livin',
#   'space',
#   'rat',
#   'race',
#   'monkeys',
#   'human',
#   'traits',
#   'mastered',
#   'numerology',
#   'big',
#   'band',
#   'theology',
#   'performed',
#   'lobotomies',
#   'telekanetic',
#   'psychology',
#   'invented',
#   'mic',
#   'start',
#   'blessin',
#   'chin',
#   'checkin',
#   'kids',
#   'make',
#   'point',
#   'like',
#   'impressionist',
#   'many',
#   'men',
#   'tried',
#   'shake',
#   'twist',
#   'mic',
#   'chords',
#   'like',
#   'double',
#   'helixes',
#   'show',
#   'made',
#   'buckle',
#   'knees',
#   'like',
#   'leg',
#   'braces',
#   'cast',
#   'spell',
#   'instrumentalist',
#   'hate',
#   'try',
#   'leave',
#   'without',
#   'shoulder',
#   'cry',
#   'infinite',
#   'let',
#   'icon',
#   'bygones',
#   'fire',
#   'bombs',
#   'ghostly',
#   'notes',
#   'haunt',
#   'tried',
#   'threats',
#   'moved',
#   'promise',
#   'stomp',
#   'shit',
#   'without',
#   'accomplice',
#   'run',
#   'guantlett',
#   'whoever',
#   'wants',
#   'high',
#   'voltage',
#   'unforgettable',
#   'sound',
#   'high',
#   'voltage',
#   'bringin',
#   'takin',
#   'high',
#   'voltage',
#   'comin',
#   'every',
#   'side',
#   'high',
#   'voltage',
#   'making',
#   'rhythm',
#   'rhyme',
#   'collide',
#   'akira',
#   'put',
#   'kink',
#   'backbones',
#   'clones',
#   'microphones',
#   'never',
#   'satisfied',
#   'rhymes',
#   'jones',
#   'spraying',
#   'bright',
#   'day',
#   'might',
#   'say',
#   'blood',
#   'types',
#   'krylon',
#   'technicolor',
#   'type',
#   'highways',
#   'write',
#   'road',
#   'rage',
#   'cages',
#   'win',
#   'cages',
#   'tin',
#   'bounce',
#   'around',
#   'surround',
#   'sound',
#   'devouring',
#   'scenes',
#   'subliminal',
#   'gangrene',
#   'paintings',
#   'things',
#   'sing',
#   'songs',
#   'karaoke',
#   'copy',
#   'bullshit',
#   'break',
#   'bones',
#   'verbally',
#   'sticks',
#   'stones',
#   'tactics',
#   'forth',
#   'dimension',
#   'compact',
#   'convention',
#   'write',
#   'rhymes',
#   'ease',
#   'track',
#   'stands',
#   'attention',
#   'ment',
#   'put',
#   'away',
#   'pencil',
#   'pistol',
#   'official',
#   'sixteen',
#   'line',
#   'rhyme',
#   'missile',
#   'risk',
#   'pick',
#   'flaws',
#   'spitting',
#   'rah',
#   'blah',
#   'blah',
#   'blah',
#   'say',
#   'saw',
#   'high',
#   'voltage',
#   'unforgettable',
#   'sound',
#   'high',
#   'voltage',
#   'bringin',
#   'takin',
#   'high',
#   'voltage',
#   'comin',
#   'every',
#   'side',
#   'high',
#   'voltage',
#   'making',
#   'rhythm',
#   'rhyme',
#   'collide',
#   'high',
#   'voltage',
#   'unforgettable',
#   'sound',
#   'high',
#   'voltage',
#   'bringin',
#   'takin',
#   'high',
#   'voltage',
#   'comin',
#   'every',
#   'side',
#   'high',
#   'voltage',
#   'making',
#   'rhythm',
#   'rhyme',
#   'collide',
#   'man',
#   'man',
#   'hand',
#   'land',
#   'roving',
#   'man',
#   'bolding',
#   'jammin',
#   'plans',
#   'ova',
#   'vics',
#   'clorousos',
#   'ferocious',
#   'spy',
#   'third',
#   'eye',
#   'extremely',
#   'high',
#   'voltage',
#   'need',
#   'ruby',
#   'corks',
#   'glasses',
#   'cause',
#   'glance',
#   'chest',
#   'might',
#   'blast',
#   'masses',
#   'subliminals',
#   'transmitted',
#   'piano',
#   'integrated',
#   'flow',
#   'calculated',
#   'nano',
#   'skills',
#   'mean',
#   'plea',
#   'sees',
#   'rhyme',
#   'hear',
#   'proceed',
#   'time',
#   'walk',
#   'walls',
#   'inanimate',
#   'obstacles',
#   'educed',
#   'reduction',
#   'cells',
#   'molecules',
#   'bring',
#   'knowledge',
#   'swallow',
#   'like',
#   'state',
#   'hologram',
#   'bot',
#   'head',
#   'fat',
#   'lip',
#   'like',
#   'collagen',
#   'telepath',
#   'another',
#   'verse',
#   'postage',
# ...
#   'mandem',
#   'linking',
#   'tings',
#   'parks',
#   'got',
#   'tune',
#   'linkin',
#   'park',
#   'like',
#   'goodbye',
#   'old',
#   'hoe’s',
#   'goodbye',
#   'cold',
#   'roads',
#   'die',
#   'postcode',
#   'young',
#   'little',
#   'mike',
#   'gold',
#   'coast',
#   'inside',
#   'bro',
#   'bro',
#   'gang',
#   'say',
#   'goodbye',
#   'hit',
#   'road',
#   'pack',
#   'disappear',
#   'better',
#   'place',
#   'cause',
#   'come',
#   'back',
#   'around',
#   'good',
#   'goodbye',
#   'good',
#   'goodbye',
#   'come',
#   'back',
#   'good',
#   'goodbye',
#   'good',
#   'goodbye',
#   'come',
#   'back'],
#  ['scream',
#   'there’s',
#   'nobody',
#   'else',
#   'fight',
#   'don’t',
#   'lose',
#   'don’t',
#   'win',
#   'i’m',
#   'wrong',
#   'i’m',
#   'halfway',
#   'right',
#   'used',
#   'get',
#   'high',
#   'dead',
#   'end',
#   'kids',
#   'abandoned',
#   'houses',
#   'shadows',
#   'live',
#   'never',
#   'higher',
#   'night',
#   'woke',
#   'driving',
#   'car',
#   'couldn’t',
#   'see',
#   'see',
#   'right',
#   'road',
#   'dissolving',
#   'like',
#   'empty',
#   'vow',
#   'couldn’t',
#   'remember',
#   'i’ve',
#   'night',
#   'knew',
#   'took',
#   'far',
#   'said',
#   'slow',
#   'remember',
#   'remember',
#   'said',
#   'slow',
#   'already',
#   'gone',
#   'scream',
#   'there’s',
#   'nobody',
#   'else',
#   'fight',
#   'don’t',
#   'lose',
#   'don’t',
#   'win',
#   'i’m',
#   'wrong',
#   'i’m',
#   'halfway',
#   'right',
#   'know',
#   'want',
#   'feels',
#   'like',
#   'i’m',
#   'paralyzed',
#   'don’t',
#   'lose',
#   'don’t',
#   'win',
#   'i’m',
#   'wrong',
#   'i’m',
#   'halfway',
#   'right',
#   'told',
#   'kid',
#   'you’re',
#   'going',
#   'way',
#   'fast',
#   'burn',
#   'bright',
#   'know',
#   'you’ll',
#   'never',
#   'last',
#   'bullshit',
#   'guess',
#   'makes',
#   'sense',
#   'woke',
#   'driving',
#   'car',
#   'said',
#   'lose',
#   'lost',
#   'control',
#   'laughed',
#   'know',
#   'standing',
#   'alone',
#   'took',
#   'far',
#   'said',
#   'slow',
#   'remember',
#   'remember',
#   'said',
#   'slow',
#   'already',
#   'gone',
#   'scream',
#   'there’s',
#   'nobody',
#   'else',
#   'fight',
#   'don’t',
#   'lose',
#   'don’t',
#   'win',
#   'i’m',
#   'wrong',
#   'i’m',
#   'halfway',
#   'right',
#   'know',
#   'want',
#   'feels',
#   'like',
#   'i’m',
#   'paralyzed',
#   'don’t',
#   'lose',
#   'don’t',
#   'win',
#   'i’m',
#   'wrong',
#   'i’m',
#   'halfway',
#   'right',
#   'halfway',
#   'right',
#   'scream',
#   'there’s',
#   'nobody',
#   'else',
#   'fight',
#   'don’t',
#   'lose',
#   'don’t',
#   'win',
#   'i’m',
#   'wrong',
#   'i’m',
#   'halfway',
#   'right',
#   'scream',
#   'there’s',
#   'nobody',
#   'else',
#   'fight',
#   'don’t',
#   'lose',
#   'don’t',
#   'win',
#   'i’m',
#   'wrong',
#   'i’m',
#   'halfway',
#   'right'],
#  ['got',
#   'aching',
#   'head',
#   'echoes',
#   'buzzing',
#   'noises',
#   'know',
#   'words',
#   'said',
#   'wish',
#   'could',
#   'turned',
#   'voices',
#   'black',
#   'white',
#   'organize',
#   'confusion',
#   'trying',
#   'get',
#   'right',
#   'spite',
#   'done',
#   'mad',
#   'trying',
#   'tear',
#   'words',
#   'could',
#   'used',
#   'scared',
#   'say',
#   'loud',
#   'cannot',
#   'break',
#   'fall',
#   'pick',
#   'right',
#   'ground',
#   'felt',
#   'invisible',
#   'let',
#   'feel',
#   'invisible',
#   'invisible',
#   'invisible',
#   'invisible',
#   'get',
#   'way',
#   'empty',
#   'feeling',
#   'got',
#   'lot',
#   'say',
#   'want',
#   'know',
#   'hurt',
#   'black',
#   'white',
#   'clear',
#   'solutions',
#   'trying',
#   'get',
#   'right',
#   'spite',
#   'done',
#   'mad',
#   'trying',
#   'tear',
#   'words',
#   'could',
#   'used',
#   'scared',
#   'say',
#   'loud',
#   'cannot',
#   'break',
#   'fall',
#   'pick',
#   'right',
#   'ground',
#   'felt',
#   'invisible',
#   'let',
#   'feel',
#   'invisible',
#   'invisible',
#   'invisible',
#   'invisible',
#   'black',
#   'white',
#   'clear',
#   'solutions',
#   'trying',
#   'get',
#   'right',
#   'spite',
#   'done',
#   'mad',
#   'trying',
#   'tear',
#   'words',
#   'could',
#   'used',
#   'scared',
#   'say',
#   'loud',
#   'cannot',
#   'break',
#   'fall',
#   'pick',
#   'right',
#   'ground',
#   'felt',
#   'invisible',
#   'let',
#   'feel',
#   'invisible',
#   'invisible',
#   'invisible',
#   'invisible',
#   'invisible',
#   'invisible',
#   'invisible',
#   'invisible'],
#  ['i’m',
#   'dancing',
#   'demons',
#   'i’m',
#   'hanging',
#   'edge',
#   'storm',
#   'clouds',
#   'gather',
#   'beneath',
#   'waves',
#   'break',
#   'head',
#   'first',
#   'hallucination',
#   'wanna',
#   'fall',
#   'wide',
#   'awake',
#   'tell',
#   'it’s',
#   'alright',
#   'tell',
#   'i’m',
#   'forgiven',
#   'tonight',
#   'nobody',
#   'save',
#   'i’m',
#   'holding',
#   'light',
#   'chasing',
#   'darkness',
#   'inside',
#   'cause',
#   'nobody',
#   'save',
#   'stare',
#   'illusion',
#   'answers',
#   'yet',
#   'come',
#   'chose',
#   'false',
#   'solution',
#   'nobody',
#   'proved',
#   'wrong',
#   'first',
#   'hallucination',
#   'wanna',
#   'fall',
#   'wide',
#   'awake',
#   'watch',
#   'ground',
#   'giving',
#   'way',
#   'tell',
#   'it’s',
#   'alright',
#   'tell',
#   'i’m',
#   'forgiven',
#   'tonight',
#   'nobody',
#   'save',
#   'i’m',
#   'holding',
#   'light',
#   'i’m',
#   'chasing',
#   'darkness',
#   'inside',
#   'cause',
#   'nobody',
#   'save',
#   'searching',
#   'somewhere',
#   'what’s',
#   'missing',
#   'right',
#   'i’ve',
#   'searching',
#   'somewhere',
#   'what’s',
#   'missing',
#   'right',
#   'wanna',
#   'fall',
#   'wide',
#   'awake',
#   'tell',
#   'it’s',
#   'alright',
#   'tell',
#   'i’m',
#   'forgiven',
#   'tonight',
#   'save',
#   'i’m',
#   'holding',
#   'light',
#   'chasing',
#   'darkness',
#   'inside',
#   'don’t',
#   'wanna',
#   'let',
#   'save',
#   'searching',
#   'somewhere',
#   'what’s',
#   'missing',
#   'right'],
#  ['stayed',
#   'signs',
#   'ignored',
#   'help',
#   'hurt',
#   'anymore',
#   'saw',
#   'brilliance',
#   'world',
#   'asleep',
#   'things',
#   'keep',
#   'say',
#   'cares',
#   'one',
#   'light',
#   'goes',
#   'sky',
#   'million',
#   'stars',
#   'flickers',
#   'flickers',
#   'cares',
#   'someone',
#   'time',
#   'runs',
#   'moment',
#   'quicker',
#   'quicker',
#   'cares',
#   'one',
#   'light',
#   'goes',
#   'well',
#   'reminders',
#   'pull',
#   'floor',
#   'feet',
#   'kitchen',
#   'one',
#   'chair',
#   'need',
#   'angry',
#   'fair',
#   'cause',
#   'see',
#   'mean',
#   'say',
#   'cares',
#   'one',
#   'light',
#   'goes',
#   'sky',
#   'million',
#   'stars',
#   'flickers',
#   'flickers',
#   'cares',
#   'someone',
#   'time',
#   'runs',
#   'moment',
#   'quicker',
#   'quicker',
#   'cares',
#   'one',
#   'light',
#   'goes',
#   'well',
#   'cares',
#   'one',
#   'light',
#   'goes',
#   'sky',
#   'million',
#   'stars',
#   'flickers',
#   'flickers',
#   'cares',
#   'someone',
#   'time',
#   'runs',
#   'moment',
#   'quicker',
#   'quicker',
#   'cares',
#   'one',
#   'light',
#   'goes',
#   'well',
#   'well'],
#  ['mama',
#   'always',
#   'told',
#   'don’t',
#   'run',
#   'don’t',
#   'run',
#   'scissors',
#   'son',
#   'you’re',
#   'gonna',
#   'hurt',
#   'someone',
#   'mama',
#   'told',
#   'look',
#   'leap',
#   'always',
#   'think',
#   'speak',
#   'watch',
#   'friends',
#   'keep',
#   'stay',
#   'along',
#   'beaten',
#   'path',
#   'never',
#   'listened',
#   'said',
#   'sharp',
#   'edges',
#   'consequences',
#   'guess',
#   'find',
#   'sharp',
#   'edges',
#   'consequences',
#   'every',
#   'scar',
#   'story',
#   'tell',
#   'should’ve',
#   'played',
#   'safer',
#   'start',
#   'loved',
#   'like',
#   'house',
#   'cards',
#   'let',
#   'fall',
#   'apart',
#   'things',
#   'couldn’t',
#   'understand',
#   'never',
#   'could’ve',
#   'planned',
#   'made',
#   'put',
#   'nose',
#   'paperbacks',
#   'instead',
#   'smoking',
#   'cigarettes',
#   'years',
#   'you’re',
#   'never',
#   'getting',
#   'back',
#   'stay',
#   'along',
#   'beaten',
#   'path',
#   'never',
#   'listened',
#   'said',
#   'sharp',
#   'edges',
#   'consequences',
#   'guess',
#   'find',
#   'sharp',
#   'edges',
#   'consequences',
#   'every',
#   'scar',
#   'story',
#   'tell',
#   'fall',
#   'live',
#   'somehow',
#   'learn',
#   'doesn’t',
#   'kill',
#   'makes',
#   'stronger',
#   'fall',
#   'live',
#   'somehow',
#   'learn',
#   'doesn’t',
#   'kill',
#   'makes',
#   'stronger',
#   'ooh',
#   'stay',
#   'along',
#   'beaten',
#   'path',
#   'never',
#   'listened',
#   'said',
#   'sharp',
#   'edges',
#   'consequences',
#   'guess',
#   'find',
#   'sharp',
#   'edges',
#   'consequences',
#   'every',
#   'scar',
#   'story',
#   'tell',
#   'fall',
#   'live',
#   'somehow',
#   'learn',
#   'doesn’t',
#   'kill',
#   'makes',
#   'stronger',
#   'fall',
#   'live',
#   'somehow',
#   'learn',
#   'doesn’t',
#   'kill',
#   'makes',
#   'stronger',
#   'ooh'],
#  ['watching',
#   'wings',
#   'cut',
#   'clouds',
#   'watching',
#   'raindrops',
#   'blinking',
#   'red',
#   'white',
#   'thinking',
#   'back',
#   'ground',
#   'fire',
#   'burning',
#   'eyes',
#   'halfway',
#   'apologize',
#   'sorry',
#   'around',
#   'sometimes',
#   'things',
#   'refuse',
#   'way',
#   'planned',
#   'sorry',
#   'around',
#   'day',
#   'understand',
#   'understand',
#   'may',
#   'forget',
#   'case',
#   'memories',
#   'cross',
#   'mind',
#   'know',
#   'left',
#   'fire',
#   'angry',
#   'eyes',
#   'never',
#   'wanted',
#   'say',
#   'goodbye',
#   'sorry',
#   'around',
#   'sometimes',
#   'things',
#   'refuse',
#   'way',
#   'planned',
#   'sorry',
#   'around',
#   'day',
#   'understand',
#   'understand',
#   'yeah',
#   'stop',
#   'telling',
#   'pump',
#   'bass',
#   'tried',
#   'call',
#   'home',
#   'nobody',
#   'would',
#   'wake',
#   'switch',
#   'time',
#   'zones',
#   'pick',
#   'bass',
#   'passed',
#   'time',
#   'wake',
#   'best',
#   'things',
#   'come',
#   'wait',
#   'time',
#   'get',
#   'pumped',
#   'road',
#   'take',
#   'ever',
#   'problem',
#   'make',
#   'mistake',
#   'wait',
#   'come',
#   'back',
#   'going',
#   'away',
#   'sorry',
#   'around',
#   'things',
#   'stand',
#   'sorry',
#   'around',
#   'day',
#   'understand',
#   'sorry',
#   'around',
#   'things',
#   'stand',
#   'sorry',
#   'around',
#   'day',
#   'understand',
#   'understand',
#   'understand',
#   'understand'],
#  ['tell',
#   'gotta',
#   'getting',
#   'lights',
#   'nobody',
#   'home',
#   'nobody',
#   'home',
#   'say',
#   'understand',
#   'giving',
#   'chance',
#   'leave',
#   'walls',
#   'keep',
#   'building',
#   'time',
#   'spent',
#   'chasing',
#   'ways',
#   'keep',
#   'losing',
#   'truth',
#   'turn',
#   'someone',
#   'else',
#   'keep',
#   'running',
#   'like',
#   'sky',
#   'falling',
#   'whisper',
#   'yell',
#   'know',
#   'yeah',
#   'know',
#   'yeah',
#   'know',
#   'talking',
#   'talking',
#   'talking',
#   'know',
#   'yeah',
#   'know',
#   'yeah',
#   'know',
#   'talking',
#   'admit',
#   'made',
#   'mistakes',
#   'might',
#   'cost',
#   'everything',
#   'hear',
#   'calling',
#   'home',
#   'walls',
#   'keep',
#   'building',
#   'time',
#   'spent',
#   'chasing',
#   'ways',
#   'keep',
#   'losing',
#   'truth',
#   'turn',
#   'someone',
#   'else',
#   'keep',
#   'running',
#   'like',
#   'sky',
#   'falling',
#   'whisper',
#   'yell',
#   'know',
#   'yeah',
#   'know',
#   'yeah',
#   'know',
#   'talking',
#   'talking',
#   'talking',
#   'know',
#   'yeah',
#   'know',
#   'yeah',
#   'know',
#   'talking',
#   'walls',
#   'keep',
#   'building',
#   'time',
#   'spent',
#   'chasing',
#   'ways',
#   'keep',
#   'losing',
#   'truth',
#   'turn',
#   'someone',
#   'else',
#   'keep',
#   'running',
#   'like',
#   'sky',
#   'falling',
#   'whisper',
#   'yell',
#   'know',
#   'yeah',
#   'know',
#   'yeah',
#   'know',
#   'talking',
#   'talking',
#   'talking',
#   'know',
#   'yeah',
#   'know',
#   'yeah',
#   'know',
#   'talking'],
#  ['starts',
#   'one',
#   'thing',
#   'know',
#   'even',
#   'matter',
#   'hard',
#   'try',
#   'keep',
#   'mind',
#   'designed',
#   'rhyme',
#   'explain',
#   'due',
#   'time',
#   'know',
#   'time',
#   'valuable',
#   'thing',
#   'watch',
#   'fly',
#   'pendulum',
#   'swings',
#   'watch',
#   'count',
#   'end',
#   'day',
#   'clock',
#   'ticks',
#   'life',
#   'away',
#   'unreal',
#   'look',
#   'watch',
#   'time',
#   'right',
#   'window',
#   'trying',
#   'hold',
#   'even',
#   'know',
#   'wasted',
#   'watch',
#   'kept',
#   'everything',
#   'inside',
#   'even',
#   'though',
#   'tried',
#   'fell',
#   'apart',
#   'meant',
#   'eventually',
#   'memory',
#   'time',
#   'tried',
#   'hard',
#   'got',
#   'far',
#   'end',
#   'even',
#   'matter',
#   'fall',
#   'lose',
#   'end',
#   'even',
#   'matter',
#   'one',
#   'thing',
#   'know',
#   'even',
#   'matter',
#   'hard',
#   'try',
#   'keep',
#   'mind',
#   'designed',
#   'rhyme',
#   'remind',
#   'tried',
#   'hard',
#   'spite',
#   'way',
#   'mocking',
#   'acting',
#   'like',
#   'part',
#   'property',
#   'remembering',
#   'times',
#   'fought',
#   'surprised',
#   'got',
#   'far',
#   'things',
#   'way',
#   'even',
#   'recognize',
#   'anymore',
#   'knew',
#   'back',
#   'comes',
#   'back',
#   'end',
#   'kept',
#   'everything',
#   'inside',
#   'even',
#   'though',
#   'tried',
#   'fell',
#   'apart',
#   'meant',
#   'eventually',
#   'memory',
#   'time',
#   'tried',
#   'hard',
#   'got',
#   'far',
#   'end',
#   'even',
#   'matter',
#   'fall',
#   'lose',
#   'end',
#   'even',
#   'matter',
#   'put',
#   'trust',
#   'pushed',
#   'far',
#   'one',
#   'thing',
#   'know',
#   'put',
#   'trust',
#   'pushed',
#   'far',
#   'one',
#   'thing',
#   'know',
#   'tried',
#   'hard',
#   'got',
#   'far',
#   'end',
#   'even',
#   'matter',
#   'fall',
#   'lose',
#   'end',
#   'even',
#   'matter'],
#  ['pretend',
#   'everything',
#   'want',
#   'look',
#   'exactly',
#   'like',
#   'always',
#   'wanted',
#   'see',
#   'pretend',
#   'forget',
#   'criminal',
#   'stealing',
#   'second',
#   'second',
#   'cause',
#   'know',
#   'pretend',
#   'way',
#   'stay',
#   'trying',
#   'bend',
#   'truth',
#   'pretend',
#   'want',
#   'lying',
#   'way',
#   'turning',
#   'back',
#   'want',
#   'pushed',
#   'aside',
#   'let',
#   'turning',
#   'back',
#   'let',
#   'take',
#   'back',
#   'life',
#   'rather',
#   'alone',
#   'turning',
#   'back',
#   'anywhere',
#   'cause',
#   'see',
#   'turning',
#   'back',
#   'worst',
#   'part',
#   'remember',
#   'taught',
#   'remember',
#   'condescending',
#   'talk',
#   'ought',
#   'remember',
#   'listening',
#   'pretended',
#   'person',
#   'fitting',
#   'think',
#   'person',
#   'really',
#   'trying',
#   'bend',
#   'truth',
#   'push',
#   'pulling',
#   'away',
#   'cause',
#   'lying',
#   'way',
#   'turning',
#   'back',
#   'want',
#   'pushed',
#   'aside',
#   'let',
#   'turning',
#   'back',
#   'let',
#   'take',
#   'back',
#   'life',
#   'rather',
#   'alone',
#   'turning',
#   'back',
#   'anywhere',
#   'cause',
#   'see',
#   'turning',
#   'back',
#   'worst',
#   'part',
#   'worst',
#   'part',
#   'wanted',
#   'never',
#   'thought',
#   'said',
#   'would',
#   'running',
#   'like',
#   'wanted',
#   'never',
#   'thought',
#   'said',
#   'would',
#   'running',
#   'like',
#   'wanted',
#   'never',
#   'thought',
#   'said',
#   'would',
#   'running',
#   'like',
#   'wanted',
#   'never',
#   'thought',
#   'said',
#   'would',
#   'running',
#   'like',
#   'turning',
#   'back',
#   'want',
#   'pushed',
#   'aside',
#   'let',
#   'turning',
#   'back',
#   'let',
#   'take',
#   'back',
#   'life',
#   'rather',
#   'alone',
#   'turning',
#   'back',
#   'anywhere',
#   'cause',
#   'see',
#   'turning',
#   'back',
#   'worst',
#   'part',
#   'worst',
#   'part'],
#  ['graffiti',
#   'decorations',
#   'sky',
#   'dust',
#   'constant',
#   'wave',
#   'tension',
#   'top',
#   'broken',
#   'trust',
#   'lessons',
#   'taught',
#   'learned',
#   'never',
#   'true',
#   'find',
#   'question',
#   'point',
#   'finger',
#   'guilty',
#   'association',
#   'point',
#   'finger',
#   'wanna',
#   'run',
#   'away',
#   'never',
#   'say',
#   'goodbye',
#   'wanna',
#   'know',
#   'truth',
#   'instead',
#   'wondering',
#   'wanna',
#   'know',
#   'answers',
#   'lies',
#   'wanna',
#   'shut',
#   'door',
#   'open',
#   'mind',
#   'paper',
#   'bags',
#   'angry',
#   'voices',
#   'sky',
#   'dust',
#   'another',
#   'wave',
#   'tension',
#   'filled',
#   'talk',
#   'taking',
#   'action',
#   'words',
#   'never',
#   'true',
#   'find',
#   'question',
#   'point',
#   'finger',
#   'guilty',
#   'association',
#   'point',
#   'finger',
#   'wanna',
#   'run',
#   'away',
#   'never',
#   'say',
#   'goodbye',
#   'wanna',
#   'know',
#   'truth',
#   'instead',
#   'wondering',
#   'wanna',
#   'know',
#   'answers',
#   'lies',
#   'wanna',
#   'shut',
#   'door',
#   'open',
#   'mind',
#   'gonna',
#   'run',
#   'away',
#   'never',
#   'say',
#   'goodbye',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'never',
#   'wonder',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'open',
#   'mind',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'gonna',
#   'run',
#   'away',
#   'wanna',
#   'run',
#   'away',
#   'never',
#   'say',
#   'goodbye',
#   'wanna',
#   'know',
#   'truth',
#   'instead',
#   'wondering',
#   'wanna',
#   'know',
#   'answers',
#   'lies',
#   'wanna',
#   'shut',
#   'door',
#   'open',
#   'mind',
#   'wanna',
#   'run',
#   'away',
#   'open',
#   'mind',
#   'wanna',
#   'run',
#   'away',
#   'open',
#   'mind',
#   'wanna',
#   'run',
#   'away',
#   'open',
#   'mind',
#   'wanna',
#   'run',
#   'away',
#   'open',
#   'mind']]

# %%
model = Word2Vec(corpus, size=300, window=5, min_count=3, sg=0, iter=50)

model.train(corpus, total_examples=len(corpus), epochs=50)
# Out:
# (656268, 871700)

# %%
model.wv.most_similar(positive=['glass'])
# Out:
# [('castle', 0.9925153255462646),
#  ('hardly', 0.9855707287788391),
#  ('crack', 0.9515681862831116),
#  ('anything', 0.6310016512870789),
#  ('anywhere', 0.6257785558700562),
#  ('breathe', 0.5744950771331787),
#  ('dream', 0.555234432220459),
#  ('wisdom', 0.5448112487792969),
#  ('justice', 0.5410251021385193),
#  ('reconciled', 0.5367980599403381)]

# %%
model.wv.most_similar(positive=['battle'])
# Out:
# [('symphony', 0.8895705938339233),
#  ('armor', 0.7653952240943909),
#  ('fuse', 0.7605004906654358),
#  ('together', 0.6912732124328613),
#  ('wide', 0.5887556672096252),
#  ('awake', 0.5605049133300781),
#  ('puts', 0.5322713851928711),
#  ('react', 0.5306293368339539),
#  ('great', 0.5216079950332642),
#  ('breaks', 0.5162221193313599)]

# %%
model.wv.most_similar(positive=['sorrow'])
# Out:
# [('borrowed', 0.7508074641227722),
#  ('hypocrites', 0.7481631636619568),
#  ('money', 0.7249287366867065),
#  ('replaced', 0.6566493511199951),
#  ('mistakes', 0.6483978033065796),
#  ('thieves', 0.6464242935180664),
#  ('paid', 0.6445585489273071),
#  ('done', 0.5902692675590515),
#  ('shock', 0.5789891481399536),
#  ('separate', 0.5686025023460388)]

# %% [markdown]
# ### Words Movers Distance

# %%
model.init_sims(replace=True)
model.wmdistance(corpus[0], corpus[1])
# Out:
# 1.1020856393302407

# %%
model.wmdistance(corpus[5], corpus[10])
# Out:
# 1.1331873600081577

# %% [markdown]
# Ler um nome de uma musica do usuario, comparar com o array de músicas e recomendar as músicas mais semelhantes
